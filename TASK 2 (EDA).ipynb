# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Some conclusions 

# There are missing values in age, cabin and embarked columns 
# We will drop cabin column since most of the values are missing
# Some columns have inappropriate datatype

# %%
#dropping the column cabin
df.drop(columns=['Cabin'],inplace=True)

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age'].plot(kind='kde')
plt.show()

# %%
df['Age'].skew()  #when the skew value is around 0 normal distributed data
# Out:
# 0.38910778230082704

# %%
#filling the age values using fillna mean method
df['Age']=df['Age'].fillna(df['Age'].mean())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
#FARE
#The data is positively skewed
#There are zero null values in the column
#the Fare column is group fare and not an individual fare we need to add a column of individual fare

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df["Fare"].plot(kind="hist")
plt.show()

# %%
df["Fare"].plot(kind="kde")
plt.show()

# %%
df['Fare'].skew()     #highly positively skewed
# Out:
# 4.787316519674893

# %%
df['Fare'].plot(kind="box")
plt.show()

# %%
df[df['Fare']>200]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 88            89         1       1
# 118          119         0       1
# 258          259         1       1
# 299          300         1       1
# 311          312         1       1
# 341          342         1       1
# 377          378         0       1
# 380          381         1       1
# 438          439         0       1
# 527          528         0       1
# 557          558         0       1
# 679          680         1       1
# 689          690         1       1
# 700          701         1       1
# 716          717         1       1
# 730          731         1       1
# 737          738         1       1
# 742          743         1       1
# 779          780         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ...

# %%
df['Fare'].isnull().sum()
# Out:
# 0

# %%
#SURVIVED CONCLUSIONS

#More than 60% of passengers didn't survived
#There are no null values

# %%
df['Survived'].value_counts().plot(kind='bar')
plt.show()

# %%
df['Survived'].value_counts().plot(kind='pie', autopct="%0.2f%%")
plt.show()

# %%
df['Survived'].isnull().sum()
# Out:
# 0

# %%
#PCLASS CONCLUSION

# Less people travelled by Pclass 2 and more people travelled by pclass 3
# There are no null values in the given data

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts().plot(kind="bar")
plt.show()

# %%
df['Pclass'].value_counts().plot(kind='pie', autopct="%0.2f%%")
plt.show()

# %%
df['Pclass'].isnull().sum()
# Out:
# 0

# %%
# SEX RELATED CONCLUSIONS

# There were more male passengers than female
# There are only two types gender in out

# %%
df['Sex'].describe()
# Out:
# count      891
# unique       2
# top       male
# freq       577
# Name: Sex, dtype: object

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Sex'].value_counts().plot(kind='pie', autopct="%0.2f%%")
plt.show()

# %%
# SIBSP CONCLUSIONS

# There isn't null value in the data 
# Many passengers are solo travelling ie 68%

# %%
df['SibSp'].describe()
# Out:
# count    891.000000
# mean       0.523008
# std        1.102743
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        8.000000
# Name: SibSp, dtype: float64

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df['SibSp'].isnull().sum()
# Out:
# 0

# %%
df['SibSp'].value_counts().plot(kind='pie', autopct="%0.1f%%")
plt.show()

# %%
# Survived Conclusions

# Parch and SibSp columns can be merged to form a new column called family_size
# We can also create a new column by the name is_alone is many of the passengers are travelling alone

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
df['Parch'].isnull().sum()
# Out:
# 0

# %%
df['Parch'].value_counts().plot(kind='bar')
plt.show()

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'].isnull().sum()
# Out:
# 2

# %%
df['Embarked'].value_counts().plot(kind='bar')
plt.show()

# %%
df['Embarked'].value_counts().plot(kind='pie', autopct="%0.1f%%")
plt.show()

# %%
#MIXED COLUMNS (Name, Cabin, Ticket)

# We need to do feature engineering to get more insights

# %%
pd.crosstab(df['Survived'], df['Pclass'])
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
pd.crosstab(df['Survived'], df['Pclass'], normalize='columns' )*100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
sns.heatmap(pd.crosstab(df['Survived'], df['Pclass'], normalize='columns' )*100)
plt.show()

# %%
pd.crosstab(df['Survived'], df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
pd.crosstab(df['Sex'], df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %%
pd.crosstab(df['Pclass'], df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %%
pd.crosstab(df['Pclass'], df['Survived'], normalize='columns')*100
# Out:
# Survived          0          1
# Pclass
# 1         14.571949  39.766082
# 2         17.668488  25.438596
# 3         67.759563  34.795322

# %%
df[df['Survived']==1]['Age'].plot(kind="kde", label="Survived")
df[df['Survived']==0]['Age'].plot(kind="kde", label="not Survived")

plt.legend()
plt.show()

# %%
df[df['Pclass']==1]['Age'].plot(kind="kde", label="p1")
df[df['Pclass']==2]['Age'].plot(kind="kde", label="p2")
df[df['Pclass']==3]['Age'].plot(kind="kde", label="p3")

plt.legend()
plt.show()

# %%
df.groupby("Pclass")['Age'].mean()
sns.boxplot(x="Pclass", y="Age", data=df)
plt.show()

# %%
sns.boxplot(x='Sex', y="Age", data=df)
plt.show()

# %%
#Feature Engineering on Fare column

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df[df['SibSp']==8]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df[df['Ticket']=='CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
dff=pd.read_csv("test.csv")
dff
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df=pd.concat([df,dff])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Ticket']=="CA. 2343"]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160       0.0       3         Sage, Master. Thomas Henry    male
# 180          181       0.0       3       Sage, Miss. Constance Gladys  female
# 201          202       0.0       3                Sage, Mr. Frederick    male
# 324          325       0.0       3           Sage, Mr. George John Jr    male
# 792          793       0.0       3            Sage, Miss. Stella Anna  female
# 846          847       0.0       3           Sage, Mr. Douglas Bullen    male
# 863          864       0.0       3  Sage, Miss. Dorothy Edith "Dolly"  female
# 188         1080       NaN       3                    Sage, Miss. Ada  female
# 342         1234       NaN       3              Sage, Mr. John George    male
# 360         1252       NaN       3        Sage, Master. William Henry    male
# 365         1257       NaN       3     Sage, Mrs. John (Annie Bullen)  female
#
# ...

# %%
df['Ticket'].value_counts()
# Out:
# Ticket
# CA. 2343        11
# CA 2144          8
# 1601             8
# PC 17608         7
# S.O.C. 14879     7
#                 ..
# 113792           1
# 36209            1
# 323592           1
# 315089           1
# 359309           1
# Name: count, Length: 929, dtype: int64

# %%
df[df['Ticket']=='CA 2144']
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 59            60       0.0       3       Goodwin, Master. William Frederick
# 71            72       0.0       3               Goodwin, Miss. Lillian Amy
# 386          387       0.0       3          Goodwin, Master. Sidney Leonard
# 480          481       0.0       3           Goodwin, Master. Harold Victor
# 678          679       0.0       3  Goodwin, Mrs. Frederick (Augusta Tyler)
# 683          684       0.0       3              Goodwin, Mr. Charles Edward
# 139         1031       NaN       3           Goodwin, Mr. Charles Frederick
# 140         1032       NaN       3              Goodwin, Miss. Jessie Allis
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 59     male  11.0      5      2  CA 2144  46.9   NaN        S
# 71   female  16.0      5      2  CA 2144  46.9   NaN        S
# 386    male   1.0      5      2  CA 2144  46.9   NaN        S
# ...

# %%
df['individual_fare']=df['Fare']/ (df['SibSp']+df['Parch']+1)

# %%
df['individual_fare'].plot(kind='box') 
plt.show()

# %%
df['individual_fare']
# Out:
# 0        3.625000
# 1       35.641650
# 2        7.925000
# 3       26.550000
# 4        8.050000
#           ...
# 413      8.050000
# 414    108.900000
# 415      7.250000
# 416      8.050000
# 417      7.452767
# Name: individual_fare, Length: 1309, dtype: float64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Family_size']=df['SibSp']+df['Parch']+1
df['Family_size']
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 413    1
# 414    1
# 415    1
# 416    1
# 417    3
# Name: Family_size, Length: 1309, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Family_type
'''
1 = alone
2-4 = small family
>5 = large family
'''

# %%
def family_type(num):
    if (num==1):
        return "alone"
    elif (num>1 and num<5):
        return "small"
    else:
        return "large"

# %%
df["Family_detail"] = df['Family_size'].apply(family_type)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.crosstab(df['Survived'], df['Family_detail'])
# Out:
# Family_detail  alone  large  small
# Survived
# 0.0              374     52    123
# 1.0              163     10    169

# %%
pd.crosstab(df['Survived'], df['Family_detail'], normalize='columns')*100
# Out:
# Family_detail      alone      large      small
# Survived
# 0.0            69.646182  83.870968  42.123288
# 1.0            30.353818  16.129032  57.876712

# %%
df['surname']=df['Name'].str.split(',').str.get(0)
df['surname']
# Out:
# 0             Braund
# 1            Cumings
# 2          Heikkinen
# 3           Futrelle
# 4              Allen
#            ...
# 413          Spector
# 414    Oliva y Ocana
# 415          Saether
# 416             Ware
# 417            Peter
# Name: surname, Length: 1309, dtype: object

# %%
df['Title']=df['Name'].str.split(',').str.get(1).str.strip().str.split(' ').str.get(0)

# %%
df['Title'].value_counts()
# Out:
# Title
# Mr.                           757
# Miss.                         262
# Mrs.                          197
# Master.                        61
# Male oMale oMale otherrr       25
# Female oMale oMale otherrr      5
# Male oMale otherr               2
# Name: count, dtype: int64

# %%
df['Title']=df['Title'].str.replace('Rev.', 'Male')
df['Title']=df['Title'].str.replace('Col.', 'Male')
df['Title']=df['Title'].str.replace('Dr.', 'Male')
df['Title']=df['Title'].str.replace('Major.', 'Male')
df['Title']=df['Title'].str.replace('Capt.', 'Male')
df['Title']=df['Title'].str.replace('the', 'Male')
df['Title']=df['Title'].str.replace('Sir.', 'Male')
df['Title']=df['Title'].str.replace('Jonkheer.', 'Male')
df['Title']=df['Title'].str.replace('Don.', 'Male')

# %%
df['Title'].value_counts()
# Out:
# Title
# Mr.                                   757
# Miss.                                 262
# Mrs.                                  197
# Master.                                61
# Male oMale oMale oMale oMalerrrr       25
# Female oMale oMale oMale oMalerrrr      5
# Male oMale oMale oMalerrr               2
# Name: count, dtype: int64

# %%
df['Title']=df['Title'].str.replace('Ms.', 'Miss.')

# %%
df['Title']=df['Title'].str.replace('Mlle.', 'Female')
df['Title']=df['Title'].str.replace('Mme.', 'Female')
df['Title']=df['Title'].str.replace('Lady.', 'Female')
df['Title']=df['Title'].str.replace('Dona.', 'Female')

# %%
df['Title'].value_counts()
# facing some problem here
# Out:
# Title
# Mr.                                   757
# Miss.                                 262
# Mrs.                                  197
# Master.                                61
# Male oMale oMale oMale oMalerrrr       25
# Female oMale oMale oMale oMalerrrr      5
# Male oMale oMale oMalerrr               2
# Name: count, dtype: int64

# %%
dd=df[df['Title'].isin(['Mr.','Miss.', 'Mrs.', "Master.", 'Male oMale oMale oMale oMalerrrr', 'Female oMale oMale oMale oMalerrrr', 'Male oMale oMale oMalerrr'])]
pd.crosstab(dd['Survived'], dd['Title'], normalize='columns')*100
# Out:
# Title     Female oMale oMale oMale oMalerrrr  \
# Survived
# 0.0                                      0.0
# 1.0                                    100.0
#
# Title     Male oMale oMale oMale oMalerrrr  Male oMale oMale oMalerrr  \
# Survived
# 0.0                                   75.0                        0.0
# 1.0                                   25.0                      100.0
#
# Title     Master.      Miss.        Mr.  Mrs.
# Survived
# 0.0          42.5  30.054645  84.332689  20.8
# 1.0          57.5  69.945355  15.667311  79.2

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# C22 C26            4
# F33                4
#                   ..
# A14                1
# E63                1
# E12                1
# E38                1
# C105               1
# Name: count, Length: 186, dtype: int64

# %%
df['Cabin'].value_counts().sum()
# Out:
# 295

# %%
df['Cabin'].isnull().sum()
# Out:
# 1014

# %%
df['Cabin'].fillna('M', inplace=True)   #M for missing values

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# M                  1014
# C23 C25 C27           6
# B57 B59 B63 B66       5
# G6                    5
# F33                   4
#                    ...
# A14                   1
# E63                   1
# E12                   1
# E38                   1
# C105                  1
# Name: count, Length: 187, dtype: int64

# %%
df['Deck']=df['Cabin'].str[0]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Deck'].value_counts()
# Out:
# Deck
# M    1014
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# T       1
# Name: count, dtype: int64

# %%
pd.crosstab(df['Deck'], df['Pclass'])
# Out:
# Pclass   1    2    3
# Deck
# A       22    0    0
# B       65    0    0
# C       94    0    0
# D       40    6    0
# E       34    4    3
# F        0   13    8
# G        0    0    5
# M       67  254  693
# T        1    0    0

# %%
pd.crosstab(df['Survived'], df['Deck'])
# Out:
# Deck      A   B   C   D   E  F  G    M  T
# Survived
# 0.0       8  12  24   8   8  5  2  481  1
# 1.0       7  35  35  25  24  8  2  206  0
